# %% [markdown]
# I need to create a chart like in the attached file.
#
# - The chart shows the price change of AUDUSD in 1 min, 10 min, 20 min, 30 min, 40 min, 50 min, 60 min, 1h, 2h, 3h, 4h, 5h, 6h after CPI data release in the US.
# - CPI miss value must be show on the chart with a black *
#
# I need to be able to plug data with any other currency and get a similar chart. For example, EURUSD or BTCUSD.
#
# I need to get a Jupyter Notebook or a Google Colar.

# %%
# !pip install Ipython

# %% [markdown]
# ![final-chart.jpeg](data:image/jpeg;base64,...)

# %%
# !pip install alpha_vantage
# Out:
# ...
#      |████████████████████████████████| 1.1 MB 8.1 MB/s
# ...
#      |████████████████████████████████| 271 kB 63.4 MB/s
# ...
#      |████████████████████████████████| 160 kB 57.9 MB/s
# ...
#      |████████████████████████████████| 144 kB 60.3 MB/s
# ...

# %%
from alpha_vantage.timeseries import TimeSeries
API_KEY='5TZIVT2E1ABEJD1S'
ts=TimeSeries(key=API_KEY,output_format='pandas')

# %%
ts = TimeSeries(key=API_KEY, output_format='pandas')

# %%
TICKER = 'EURUSD'
TIMEFRAME = '1min'

# %%
data, meta_data = ts.get_intraday(symbol=TICKER,interval=TIMEFRAME, outputsize='full')

# %%
data
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2022-01-21 05:01:00   1.1339   1.1340  1.1335    1.1339        0.0
# 2022-01-21 05:00:00   1.1339   1.1340  1.1335    1.1339        0.0
# 2022-01-21 04:59:00   1.1338   1.1340  1.1336    1.1339        0.0
# 2022-01-21 04:58:00   1.1338   1.1340  1.1335    1.1339        0.0
# 2022-01-21 04:57:00   1.1339   1.1341  1.1337    1.1338        0.0
# ...                      ...      ...     ...       ...        ...
# 2022-01-20 05:06:00   1.1350   1.1350  1.1346    1.1348        0.0
# 2022-01-20 05:05:00   1.1349   1.1350  1.1346    1.1350        0.0
# 2022-01-20 05:04:00   1.1351   1.1352  1.1346    1.1349        0.0
# 2022-01-20 05:03:00   1.1350   1.1352  1.1348    1.1351        0.0
# 2022-01-20 05:02:00   1.1349   1.1350  1.1345    1.1350        0.0
#
# [1440 rows x 5 columns]

# %%
df=data.iloc[:,:1]

# %%
df
# Out:
#                      1. open
# date
# 2022-01-21 05:01:00   1.1339
# 2022-01-21 05:00:00   1.1339
# 2022-01-21 04:59:00   1.1338
# 2022-01-21 04:58:00   1.1338
# 2022-01-21 04:57:00   1.1339
# ...                      ...
# 2022-01-20 05:06:00   1.1350
# 2022-01-20 05:05:00   1.1349
# 2022-01-20 05:04:00   1.1351
# 2022-01-20 05:03:00   1.1350
# 2022-01-20 05:02:00   1.1349
#
# [1440 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1440 entries, 2022-01-21 05:01:00 to 2022-01-20 05:02:00
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   1. open  1440 non-null   float64
# dtypes: float64(1)
# memory usage: 22.5 KB

# %%
import datetime

# %%
ReqDateTime=datetime.datetime(2022,1,20,8,30,0)

# %%
df.loc['2022-1-20 8:30:00','1. open']
# Out:
# date
# 2022-01-20 08:30:00    1.1343
# Name: 1. open, dtype: float64

# %%
i=[1,10,20,30,40,50,60,120,180,240,300,360]

# %%
x=[]

# %%
i[0]
# Out:
# 1

# %%
TimeChange=datetime.timedelta(minutes=i[0])

# %%
NewTime=ReqDateTime+TimeChange

# %%
NewTime
# Out:
# datetime.datetime(2022, 1, 20, 8, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1440 entries, 2022-01-21 05:01:00 to 2022-01-20 05:02:00
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   1. open  1440 non-null   float64
# dtypes: float64(1)
# memory usage: 22.5 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1440 entries, 2022-01-21 05:01:00 to 2022-01-20 05:02:00
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   1. open  1440 non-null   float64
# dtypes: float64(1)
# memory usage: 22.5 KB

# %%
df.loc['2022-1-20 8:30:00','1. open']
# Out:
# date
# 2022-01-20 08:30:00    1.1343
# Name: 1. open, dtype: float64

# %%
df
# Out:
#                      1. open
# date
# 2022-01-21 05:01:00   1.1339
# 2022-01-21 05:00:00   1.1339
# 2022-01-21 04:59:00   1.1338
# 2022-01-21 04:58:00   1.1338
# 2022-01-21 04:57:00   1.1339
# ...                      ...
# 2022-01-20 05:06:00   1.1350
# 2022-01-20 05:05:00   1.1349
# 2022-01-20 05:04:00   1.1351
# 2022-01-20 05:03:00   1.1350
# 2022-01-20 05:02:00   1.1349
#
# [1440 rows x 1 columns]

# %%
o=df.loc['2022-01-20 8:30:00','1. open']
o
# Out:
# date
# 2022-01-20 08:30:00    1.1343
# Name: 1. open, dtype: float64

# %%
tim=['2022-01-20 8:30:00','2022-01-20 8:31:00','2022-01-20 8:40:00','2022-01-20 8:50:00','2022-01-20 9:00:00','2022-01-20 9:10:00','2022-01-20 9:20:00','2022-01-20 9:30:00','2022-01-20 10:30:00','2022-01-20 11:30:00','2022-01-20 12:30:00','2022-01-20 1:30:00','2022-01-20 2:30:00']

# %%
import numpy as np
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
o=float(o)
o
# Out:
# 1.1343

# %%
x=[]

for i in np.arange(11):
    o=df.loc[tim[i],'1. open']
    o=float(o)
    x.append(o)

# %%
x
# Out:
# [1.1343,
#  1.1346,
#  1.1354,
#  1.1357,
#  1.1352,
#  1.1354,
#  1.1349,
#  1.1343,
#  1.1338,
#  1.1337,
#  1.1331]

# %%
s=[]

for i in np.arange(1,11):
    o=(x[i]-x[0])
    s.append(o)

# %%
s
# Out:
# [0.00029999999999996696,
#  0.0010999999999998789,
#  0.0013999999999998458,
#  0.0008999999999999009,
#  0.0010999999999998789,
#  0.0005999999999999339,
#  0.0,
#  -0.000500000000000167,
#  -0.000600000000000156,
#  -0.0012000000000000899]

# %%
s_formated=[round(elem,4) for elem in s]

# %%
s_formated
# Out:
# [0.0003,
#  0.0011,
#  0.0014,
#  0.0009,
#  0.0011,
#  0.0006,
#  0.0,
#  -0.0005,
#  -0.0006,
#  -0.0012]

# %%
s_cloumn=['1min','10min','20min','30min','40min','50min','1hr','2hr','3hr','4hr',]

# %%
df=pd.DataFrame(s_formated,index=s_cloumn)

# %%
df
# Out:
#             0
# 1min   0.0003
# 10min  0.0011
# 20min  0.0014
# 30min  0.0009
# 40min  0.0011
# 50min  0.0006
# 1hr    0.0000
# 2hr   -0.0005
# 3hr   -0.0006
# 4hr   -0.0012

# %%
dfT=df.T

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams["figure.figsize"] = [10, 6]
dfT.plot(kind='bar')
